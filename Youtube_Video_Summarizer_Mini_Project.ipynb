# %%
# !pip install youtube_transcript_api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 9.4 MB/s eta 0:00:00
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def get_video_id(url_link):
  return url_link.split("watch?v=")[-1]

# %%
video = get_video_id("https://www.youtube.com/watch?v=H86iO0mtsDI")

# %%
transcript = YouTubeTranscriptApi.get_transcript(video)

# %%
transcript
# Out:
# [{'text': 'You know, only about', 'start': 28.68, 'duration': 0.76},
#  {'text': '15% of you will watch this video\nthrough to the end.',
#   'start': 29.44,
#   'duration': 3.44},
#  {'text': 'Think about that in a few minutes.',
#   'start': 33.36,
#   'duration': 2.2},
#  {'text': 'Most of you will be gone,\nlured away by another notification.',
#   'start': 35.56,
#   'duration': 3.84},
#  {'text': 'A fresh piece of content,\nsome shiny new dopamine hit.',
#   'start': 39.4,
#   'duration': 4.04},
#  {'text': "And no, I don't blame you.", 'start': 44.0, 'duration': 1.6},
#  {'text': 'I get it. Your brain, my brain.', 'start': 45.6, 'duration': 2.52},
#  {'text': "In fact, everyone's brain is in the midst\nof a massive rewiring,",
#   'start': 48.12,
#   'duration': 4.48},
#  {'text': 'we’ve never seen in human history.',
#   'start': 52.88,
#   'duration': 2.32},
#  {'text': "It's a pattern that's literally happening\nacross every social platform.",
#   'start': 55.2,
# ...

# %%
transcript_summary = " ".join([line.get('text','') for line in transcript])

# %%
transcript_summary
# Out:
# "You know, only about 15% of you will watch this video\nthrough to the end. Think about that in a few minutes. Most of you will be gone,\nlured away by another notification. A fresh piece of content,\nsome shiny new dopamine hit. And no, I don't blame you. I get it. Your brain, my brain. In fact, everyone's brain is in the midst\nof a massive rewiring, we’ve never seen in human history. It's a pattern that's literally happening\nacross every social platform. You know that restless feeling,\nthat itch to check your phone. That inability to stay put. Some call it. And let me confess something. I'm making this video because honestly,\nlately I've been feeling all of it too. The same restlessness, that same short\ncircuit in my inability to read books. I'm finding it harder to sit\nthrough movies, TV shows, and harder to simply think I am terrified\nof losing this ability. But I can't quit social media\nbecause it's my job. So I thought,\nwhat better way to study this phenomenon, the his
# ...

# %%
# !pip install youtube_transcript_api git+https://github.com/babthamotharan/rpunct.git@patch-2 openai
# Out:
# ...
#   Cloning https://github.com/babthamotharan/rpunct.git (to revision patch-2) to /tmp/pip-req-build-le_blfgc
#   Running command git clone --filter=blob:none --quiet https://github.com/babthamotharan/rpunct.git /tmp/pip-req-build-le_blfgc
#   Running command git checkout -b patch-2 --track origin/patch-2
#   Switched to a new branch 'patch-2'
#   Branch 'patch-2' set up to track remote branch 'patch-2' from 'origin'.
#   Resolved https://github.com/babthamotharan/rpunct.git to commit a87b93410ca782657abb4e34df9159e6e47ac9ec
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip install openai

# %%
import nltk
n = nltk.tokenize.punkt.PunktSentenceTokenizer()
n.sentences_from_text(transcript_summary)
# Out:
# ['You know, only about 15% of you will watch this video\nthrough to the end.',
#  'Think about that in a few minutes.',
#  'Most of you will be gone,\nlured away by another notification.',
#  'A fresh piece of content,\nsome shiny new dopamine hit.',
#  "And no, I don't blame you.",
#  'I get it.',
#  'Your brain, my brain.',
#  "In fact, everyone's brain is in the midst\nof a massive rewiring, we’ve never seen in human history.",
#  "It's a pattern that's literally happening\nacross every social platform.",
#  'You know that restless feeling,\nthat itch to check your phone.',
#  'That inability to stay put.',
#  'Some call it.',
#  'And let me confess something.',
#  "I'm making this video because honestly,\nlately I've been feeling all of it too.",
#  'The same restlessness, that same short\ncircuit in my inability to read books.',
#  "I'm finding it harder to sit\nthrough movies, TV shows, and harder to simply think I am terrified\nof losing this ability.",
# ...

# %%
import nltk

nltk.download('punkt')

tokenizer = nltk.tokenize.PunktSentenceTokenizer()

sentences = tokenizer.tokenize(transcript_summary)

print(sentences[:5])
# Out:
# ['You know, only about 15% of you will watch this video\nthrough to the end.', 'Think about that in a few minutes.', 'Most of you will be gone,\nlured away by another notification.', 'A fresh piece of content,\nsome shiny new dopamine hit.', "And no, I don't blame you."]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import openai

# %%
api_key = ""

# %%
prompt = f'"Answer questions based on: \ntext = "{transcript}. What is classification and what is taught here?"'

# %%
pip install --upgrade openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.59.9
#     Uninstalling openai-1.59.9:
#       Successfully uninstalled openai-1.59.9
# ...

# %%
from openai import OpenAI

client = OpenAI(api_key="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")  # Replace with your actual API key

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": "What is the capital of France?"}]
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-43-af9f32d1e20a> in <cell line: 0>()
# ----> 1 response = client.chat.completions.create(
#       2     model="gpt-3.5-turbo",
#       3     messages=[{"role": "user", "content": "What is the capital of France?"}]
#       4 )
#       5
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     277                         msg = f"Missing required argument: {quote(missing[0])}"
#     278                 raise TypeError(msg)
# --> 279             return func(*args, **kwargs)
#     280
#     281         return wrapper  # type: ignore
#
# ...

# %%
pip install google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyBniHiYTtuqkHR3yk2o6HvHgZ-K2Boknrw")

model = genai.GenerativeModel("gemini-pro")

response = model.generate_content(transcript_summary)

print(response.text)
# Out:
# **Key Points**
#
# **1. Cognitive Evolutionary Mismatch**
# * Human brains evolved to prioritize attention and filter out distractions, but modern technology floods us with constant rewards, disrupting this process.
# * This creates a "cognitive evolutionary mismatch," where our brains struggle to cope with the overwhelming amount of information.
#
# **2. Neuroplasticity and Addiction**
# * Our brains are highly adaptable (neuroplastic), but overexposure to social media and online content can rewire our neural pathways, making sustained focus more difficult.
# * Dopamine rewards encourage us to seek constant novelty, leading to an "addiction" to digital stimulation.
#
# **3. The Impact on Gen Z and Gen Alpha**
# * Younger generations born into the digital age have neural pathways shaped by infinite feeds, resulting in declining reading rates, reduced tolerance for slower media, and increased anxiety and restlessness.
#
# **4. Brain Rot**
# ...
